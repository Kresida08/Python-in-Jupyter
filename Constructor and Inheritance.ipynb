# %% [markdown]
# Constructor and Inheritance

# %%
class Computer:
    pass

c1 = Computer()
c2 = Computer()
# gives address of the object in heap memory
print (id(c1))
print (id(c2))
# Out:
# 3060850510544
# 3060848454672

# %%
#Error code.

class Computer:
    def __init__ (self):
        self.name = "Kres"
        self.age = 28

    def __init__ (self):
        self.age = 39
    def compare (self, other):
        if (self.age == other.age):
            return True 
        else:
            return False

    c1 = Computer()
    c2 = Computer()

    c1.age = 21
    c1.name = "Lionel"

    print (c1.name)
    print (c1.age)

    c1.update()
    print (c1.age, " ".c2.age)

    print (c1.compare(c2))
# Out:
# Lionel
# 21
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Error code.
# ----> 3 class Computer:
#       4     def __init__ (self):
#       5         self.name = "Kres"
#
# Cell In[2], line 25, in Computer()
#      22 print (c1.name)
#      23 print (c1.age)
# ---> 25 c1.update()
#      26 print (c1.age, " ".c2.age)
#      28 print (c1.compare(c2))
#
# AttributeError: 'Computer' object has no attribute 'update'

# %%
class Computer:
    def __init__(self):
        self.name = "Kres"
        self.age = 39

    def compare(self, other):
        if self.age == other.age:
            return True
        else:
            return False


# Objects must be outside the class
c1 = Computer()
c2 = Computer()

c1.age = 21
c1.name = "Lionel"

print(c1.name)
print(c1.age)

print(c1.age, c2.age)

print(c1.compare(c2))
# Out:
# Lionel
# 21
# 21 39
# False

# %%
# define a variable inside init --- instance variable
# define a variable outside init and inside class --- class variable

#Inheritance

class A:
    def feature1(self):
        print("Feature 1")
    
    def feature2(self):
        print("Feature 2")
    

class B(A):
    def feature3(self):
        print("Feature 3")
    def feature4(self):
        print("Feature 4")
        
b1=B()
b1.feature1()
b1.feature3()
# Out:
# Feature 1
# Feature 3

# %%
#Constructor Inheritance

class A:
    def __init__(self):
        print ("In class A")

    def feature1(self):
        print ("Feature 1")

    def feature2(self):
        print ("Feature 2")

class B(A):
    def __init__(self):
        print("In class B")
        super().__init__()

    def feature3(self):
        print ("Feature 3")
    def feature4(self):
        print ("Feature 4")

b1=B()
b1.feature1()
b1.feature3()
# Out:
# In class B
# In class A
# Feature 1
# Feature 3

# %%
#Constructor Inheritance with Multiple Inheritance and MRO - Method Resolution Order

class A:
    def __init__(self):
        print ("In class A")

    def feature1(self):
        print ("Feature 1")

    def feature2(self):
        print("Feature 2")

class B():
    def __init__(self):
        print ("In class B")

    def feature3(self):
        print ("Feature 3")
    def feature4(self):
        print ("Feature 4")

class C(A,B):
    def __init__(self):
        print("In class C")
        super().__init__()
    def feature6(self):
        print ("Feature 6")
    def feature7(self):
        print ("Feature 7")

b1=B()
b1.feature3()

c1=C()
# Out:
# In class B
# Feature 3
# In class C
# In class A
