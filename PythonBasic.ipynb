# %%
i="Hello World"
print(i)
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# VARIABLES & DATA TYPES

# %%
1+1
# Out:
# 2

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
#Check data type
print (type(1))
print (type ("Lioness"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Input the value in a variable.
first_name = "Kresida"
last_name = "Feds"

# %%
#Print the value with the sentence and then give it in the format.
print ("My first name is {} and last name is {}".format(first_name, last_name))
print ("My First name is {first} and last name is {second}".format(first=first_name, second=last_name))
# Out:
# My first name is Kresida and last name is Feds
# My First name is Kresida and last name is Feds

# %%
#To get the length of the input value.
len("Kresida Feds")
# Out:
# 12

# %% [markdown]
# PYTHON DATA STRUCTURES AND BOOLEANS.

# %%
#To get to know the type of the data inserted.
type (True)
# Out:
# bool

# %%
#String in-built functions.
my_str = "Kresida"
print (my_str)
# Out:
# Kresida

# %%
print (my_str.capitalize()) #Converts to capital letters the first char.
print (my_str.lower()) #Returns lower char string.
print (my_str.isalnum())
print (my_str.isdigit())
print (my_str.endswith("a"))
print (my_str.endswith("K"))
print (my_str.startswith("K"))
# Out:
# Kresida
# kresida
# True
# False
# True
# False
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not True
# Out:
# False
