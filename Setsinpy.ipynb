# %% [markdown]
# SETS IN PTYHON.
# Set is an unordered collection datatypes, which is iterable, unchangeable, unindexable and does not have duplicate values. Set is based on data structure hash table.

# %%
set_var = set()
print (type(set_var))
# Out:
# <class 'set'>

# %%
set_var= {11,12,13,14,15,16,17}
print(set_var)
# Out:
# {16, 17, 11, 12, 13, 14, 15}

# %%
#Won't show the repeated value, will show only the number once.
var = {7,8,9,7,9,10,7,9,10,11}
print(var)
# Out:
# {7, 8, 9, 10, 11}

# %%
#In-Bulit Functions of set
var.add(110)  #Will add the mentioned number at the end of the list, wont take the same number again and again.
print(var)
# Out:
# {7, 8, 9, 10, 11, 110}

# %%
#Created a set of numbers. 
set1 = {11,12,13,14,15,16,17}
print(set1)
#Add 20 in the list.
set1.add(20)
print (set1)
#Created another list.
set2 = {10,30,40,50}
print(set2)
# Out:
# {16, 17, 11, 12, 13, 14, 15}
# {16, 17, 20, 11, 12, 13, 14, 15}
# {40, 10, 50, 30}
# set()

# %%
#Perform functions of union, intersection and differnece. You must have an element in the intersection. (Common element in both the set.)
set_1={7,8,9,10,11}
set_2={10,11,12,13}

set_1.intersection_update(set_2)
print(set_1)
# Out:
# {10, 11}

# %%
set_0 = {12,13,14,15}
for x in set_0:
   print(x)
#Semi-Colon should be given, Space before print, will give all the numbers in vertical format of the data.
# Out:
# 12
# 13
# 14
# 15
